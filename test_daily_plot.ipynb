# %%
import generate_all_spectra as gas

# %%
gas.one_day_proc("/nas7a/beam/beam-data/202601/beam20260123/")
# Out:
# [ 2026-01-25 05:11:57.599650 ], Processing /nas7a/beam/beam-data/202601/beam20260123/ in original mode
# Processing 1 of 9 files
# Flux factor csv file does not exist. Setting correction factors to unity.
# No background csv file provided. Setting background flux to zero.
# Data time range is from 2026-01-23T16:05:00.063 to 2026-01-23T17:04:59.996
# Data has 56076 time stamps and 3072 frequency channels
# Input frequency range is less than 100. Assuming unit in MHz.
# Reading dynamic spectrum for stokes IV
# Median of the subtracted background flux (Jy) 0.0
# RMS of the subtracted background flux (Jy) 0.0
# Processing 2 of 9 files
# Flux factor csv file does not exist. Setting correction factors to unity.
# No background csv file provided. Setting background flux to zero.
# Data time range is from 2026-01-23T17:06:00.021 to 2026-01-23T18:05:59.954
# Data has 56076 time stamps and 3072 frequency channels
# Input frequency range is less than 100. Assuming unit in MHz.
# ...
